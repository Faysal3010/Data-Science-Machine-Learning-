# %% [markdown]
# <a href="https://colab.research.google.com/github/Faysal3010/Data-Science-Machine-Learning-/blob/main/Linear_Regression_with_One_Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optinal Lab: Model Representation
#
# ![alt text](/Screenshot_8.png)

# %% [markdown]
# ## **Goals**
#
# In this lab you will:
#
#
# *   Learn to implement the model f(w,b) for linear regression with one variable
#
# ## **Notation**
# Here is a summary of some of the notation you will encounter.
#
# <table>
# <tr><th>General Notation</th><th>Description</th><th>Python (if applicable)</th></tr><tr><td>a</td><td>scalar, non bold</td><td></td></tr><tr>
# <td><b>a</b></td><td>vector, bold</td><td></td></tr>
#
# <tr><td><b>Regression</b></td><td></td><td></td></tr>
# <tr><td><b>x</b></td><td>Training Example feature value (in this lab - Size (1000 sqft))</td><td>x_train</td></tr>
#
# <tr><td><b>y</b></td>Training Example targets (in this lab price (1000S of dollars))<td></td>y_train<td></td></tr>
#
# <tr><td><b>x<sup>(i)</sup>,y<sup>(i)</sup></b></td><td>i<sub>th</sub> Training Example </td><td> x_i,y_i</td></tr>
#
#
# <tr><td>m</td><td>Number of training example </td><td></td></tr>
#
# <tr><td><b>w</b></td><td>parameter : weight</td><td>w</td></tr>
#
# <tr><td><b>b</b></td><td>parameter : bias</td><td>b</td></tr>
#
# <tr><td><b>f<sub>w,b</sub>(x<sup>(i)</sup>)</b></td><td>The result of the model evaluation at x<sup>(i)</sup> parameterized by w,b : <b>f<sub>w,b</sub>(x<sup>(i)</sup>)=wx<sup>(i)</sup>+b</b> </td><td>fwb</td></tr>
#
# </table>

# %% [markdown]
# ## Tools
# In this lab you make use of:
#
#
# *   NumPy, a popular library for scientific coumputing
# *   Matplotlib, a popular library for plotting data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)

x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m = len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
for i in range(m):
  x_i = x_train[i]
  y_i = y_train[i]
  print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)
# (x^(1), y^(1)) = (2.0, 500.0)

# %%
plt.scatter(x_train,y_train,marker="x",c='r')
plt.title("Sajoni Housing Prices")
plt.xlabel("Size (100 sqft)")
plt.ylabel("Price (in 100s of dollars)")
plt.show()

# %%
w,b=200,100
f_wb=[0]*m
def model_output(x,w,b):
  for i in range(m):
    f_wb[i]=w*x[i]+b
  return f_wb

# %%
def show():
  tmp_f_wb = model_output(x_train,w,b)
  plt.plot(x_train,tmp_f_wb,c='b',label='prediction')
  plt.scatter(x_train,y_train,marker="x",c='r',label='Actual values')
  plt.scatter(value,cost,marker="X",c='g')
  plt.title("Sajoni Housing Prices")
  plt.xlabel("Size (100 sqft)")
  plt.ylabel("Price (in 100s of dollars)")
  plt.legend()
  plt.show()

# %%
value=float(input())
cost=w*value+b
print(f"value:{cost}")
show()
# Out:
# 1.4
# value:100.0
